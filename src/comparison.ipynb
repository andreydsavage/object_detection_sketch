# %%
import pandas as pd
import json
import glob
import re

# Загрузка всех файлов
files = glob.glob('../../data/*/*_*_stats.json')
files
data = []

for f in files:
    with open(f, 'r') as file:
        stats = json.load(file)
        stats['file'] = f
        data.append(stats)

# Создание DataFrame
df = pd.DataFrame(data)

def extract_model_name(filepath):
    """
    Извлекает имя модели из пути к файлу
    Пример: '../../data/output/yolo_cuda_stats.json' -> 'yolo'
            '../../data/output/frcnn_onnx_cuda_stats.json' -> 'frcnn_onnx'
    """
    # Получаем имя файла без пути
    filename = filepath.split('/')[-1]
    # Убираем '_stats.json' и возможные суффиксы устройств
    model_name = filename.replace('_stats.json', '')
    # Убираем суффиксы _cuda, _cpu в конце
    model_name = re.sub(r'_(cuda|cpu)$', '', model_name)
    return model_name

# Применяем функцию
df['model_name'] = df['file'].apply(extract_model_name)

# Результат

# %%
df.sort_values('fps_model_inference', ascending=False)[['model_name', 'fps_model_inference', 'mean']].round(2)
# Out:
#               model_name  fps_model_inference   mean
# 6        yolo_v5s_crowd1               124.24   8.05
# 16  yolo_tensorRT_crowd1                98.23  10.18
# 18  yolo_tensorRT_crowd2                89.95  11.12
# 10    yolo_tensor_crowd1                86.47  11.56
# 9   yolo_tensorRT_crowd3                81.48  12.27
# 21  yolo_tensorRT_crowd4                78.55  12.73
# 4        yolo_v5s_crowd2                69.81  14.32
# 12    yolo_tensor_crowd3                68.24  14.65
# 0   yolo_tensorRT_crowd5                62.44  16.02
# 14    yolo_tensor_crowd2                56.78  17.61
# 3        yolo_v5s_crowd3                51.85  19.29
# 15  yolo_tensorRT_crowd6                47.64  20.99
# 11    yolo_tensor_crowd4                47.38  21.11
# 5   yolo_tensorRT_crowd7                37.74  26.50
# 22       yolo_v5s_crowd4                32.16  31.09
# 2   yolo_tensorRT_crowd8                30.52  32.77
# 1     yolo_tensor_crowd5                24.97  40.04
# 7        yolo_v5s_crowd5                23.44  42.66
# 20    yolo_tensor_crowd6                19.68  50.81
# 19       yolo_v5s_crowd6                18.42  54.29
# 13       yolo_v5s_crowd7                15.11  66.16
# 17    yolo_tensor_crowd7                13.90  71.92
# 23    yolo_tensor_crowd8                13.80  72.46
# 8        yolo_v5s_crowd8                13.11  76.27

# %%
# df
